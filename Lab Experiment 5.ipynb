# %%
import numpy as np

# %%
array = np.random.randint(1,100,16)
array
# Out:
# array([85, 15, 12, 88, 37, 34, 50, 21, 39, 72, 65, 60, 18, 22, 49, 14],
#       dtype=int32)

# %%
array.mean()
# Out:
# np.float64(42.5625)

# %%
np.percentile(array,25)
# Out:
# np.float64(20.25)

# %%
np.percentile(array,50)
# Out:
# np.float64(38.0)

# %%
np.percentile(array,75)
# Out:
# np.float64(61.25)

# %%
np.percentile(array,100)
# Out:
# np.float64(88.0)

# %%
def outDetection(array):
    sorted(array)
    Q1,Q3=np.percentile(array,[25,75])
    IQR=Q3-Q1
    lr=Q1-(1.5*IQR)
    ur=Q3+(1.5*IQR)
    return lr,ur

# %%
lr,ur=outDetection(array)
lr,ur
# Out:
# (np.float64(-41.25), np.float64(122.75))

# %%
import seaborn as sns
# %matplotlib inline

sns.displot(array)

# %%
sns.histplot(array, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
new_array=array[(array>lr) & (array<ur)]
new_array
# Out:
# array([85, 15, 12, 88, 37, 34, 50, 21, 39, 72, 65, 60, 18, 22, 49, 14],
#       dtype=int32)

# %%
sns.displot(new_array)

# %%
lr1,ur1=outDetection(new_array)
lr1,ur1
# Out:
# (np.float64(-41.25), np.float64(122.75))

# %%
final_array=new_array[(new_array>lr1) & (new_array<ur1)]
final_array
# Out:
# array([85, 15, 12, 88, 37, 34, 50, 21, 39, 72, 65, 60, 18, 22, 49, 14],
#       dtype=int32)

# %%
sns.histplot(final_array,kde=True)
# Out:
# <Axes: ylabel='Count'>
